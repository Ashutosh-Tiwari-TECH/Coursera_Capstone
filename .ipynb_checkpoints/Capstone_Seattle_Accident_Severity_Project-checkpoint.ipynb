# %%
import pandas as pd
import numpy as np

# %%
Main_DS = pd.read_csv(r"C:\Users\ashur\Downloads\Data-Collisions.csv")
# Out:
# C:\Users\ashur\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Main_DS.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# ...

# %%
Main_DS.dtypes
# Out:
# SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# ...

# %%
Main_DS.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY      COLDETKEY         INTKEY  SEVERITYCODE.1  \
# count  194673.000000  194673.000000   65070.000000   194673.000000
# mean   141091.456350  141298.811381   37558.450576        1.298901
# std     86634.402737   86986.542110   51745.990273        0.457778
# min      1001.000000    1001.000000   23807.000000        1.000000
# ...

# %%
ds=Main_DS.drop(["SEVERITYCODE.1","OBJECTID","INCKEY","COLDETKEY","REPORTNO","INTKEY","EXCEPTRSNCODE","EXCEPTRSNDESC","INATTENTIONIND","PEDROWNOTGRNT","SDOTCOLNUM","SEGLANEKEY","CROSSWALKKEY"],axis=1)

# %%
ds.dropna(subset = ["X","WEATHER","ROADCOND","LIGHTCOND","UNDERINFL"],inplace=True)
ds["UNDERINFL"]=ds["UNDERINFL"].replace(["0","1"],["N","Y"])
ds.shape
# Out:
# (184167, 25)

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed and imported!

# %%
seattle_latitude = 47.608013
seattle_longitude = -122.335167
mexico_map = folium.Map(location=[seattle_latitude, seattle_longitude], zoom_start=10)
mexico_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import matplotlib.pyplot as plt

# %%
ds.plot(kind="scatter",x="X",y="Y",alpha=0.4)
plt.show()

# %%
BBox = ((ds.Y.min(),   ds.Y.max(), ds.X.min(), ds.X.max()))
BBox
# Out:
# (47.49557292, 47.73414158, -122.41909109999999, -122.2389494)

# %%
ruh_m = plt.imread(r'C:\Users\ashur\Downloads\map.png')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(ds.Y, ds.X, zorder=1, alpha= 0.2, c='b', s=1)
ax.set_title('Plotting Collision Data on seattle city')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
ds["UNDERINFL"].value_counts()
# Out:
# N    175308
# Y      8859
# Name: UNDERINFL, dtype: int64

# %%
ds["WEATHER"].value_counts()
# Out:
# Clear                       108833
# Raining                      31987
# Overcast                     27105
# Unknown                      13846
# Snowing                        888
# Other                          765
# Fog/Smog/Smoke                 553
# Sleet/Hail/Freezing Rain       112
# Blowing Sand/Dirt               49
# Severe Crosswind                24
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64

# %%
ds["ROADCOND"].value_counts()
# Out:
# Dry               121871
# Wet                46009
# Unknown            13795
# Ice                 1174
# Snow/Slush           984
# Other                116
# Standing Water       102
# Sand/Mud/Dirt         63
# Oil                   53
# Name: ROADCOND, dtype: int64

# %%
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
convert_dict = {'SEVERITYCODE':int } 
convert_dict2 = {'X':int,'Y':int,'LOCATION':str } 

ds.astype(convert_dict2)

dataframe_filtered_rows = ds.loc[(ds['X'] >= -122.41909109999999) & (ds['X'] < -122.2389494)& (ds['Y'] >= 47.49557292)
                                & (ds['Y'] <= 47.73414158)]
dataframe_filtered_rows.shape

ds_column = ds['SEVERITYCODE'].value_counts()

ds_column=ds_column.reset_index()
ds_column
# Out:
#    index  SEVERITYCODE
# 0      1        128154
# 1      2         56013

# %%
mdl_data=ds[['ADDRTYPE','LOCATION','COLLISIONTYPE','WEATHER','ROADCOND','LIGHTCOND','SEVERITYCODE']]
mdl_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D1E2526F48>]],
#       dtype=object)

# %%
plt.scatter(mdl_data.LIGHTCOND, mdl_data.SEVERITYCODE,  color='blue')
plt.xlabel("Light condition")
plt.ylabel("Severity Type")
plt.show()

# %%
msk = np.random.rand(len(mdl_data)) < 0.8
train = mdl_data[msk]
test = mdl_data[~msk]

# %%
plt.scatter(train.LIGHTCOND, train.SEVERITYCODE,  color='blue')
plt.xlabel("Light condition")
plt.ylabel("Severity Type")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
mdl_data=pd.DataFrame(mdl_data)
mdl_data = mdl_data.dropna()
mdl_data = mdl_data.reset_index(drop=True)
X=mdl_data[['ADDRTYPE','COLLISIONTYPE','WEATHER','ROADCOND','LIGHTCOND']].values

le_sex = preprocessing.LabelEncoder()
le_sex.fit(['Block','Intersection'])
X[:,0] = le_sex.transform(X[:,0])

le_Col = preprocessing.LabelEncoder()
le_Col.fit(['Angles','Sideswipe','Parked Car','Other','Cycles','Rear Ended','Head On','Left Turn','Pedestrian','Right Turn'])
X[:,1] = le_Col.transform(X[:,1])

le_Wthr = preprocessing.LabelEncoder()
le_Wthr.fit(['Overcast','Raining','Clear','Unknown','Other','Snowing','Fog/Smog/Smoke','Sleet/Hail/Freezing Rain','Blowing Sand/Dirt','Severe Crosswind','Partly Cloudy'])
X[:,2] = le_Wthr.transform(X[:,2])

le_rod = preprocessing.LabelEncoder()
le_rod.fit(['Wet','Dry','Unknown','Snow/Slush','Ice','Other','Sand/Mud/Dirt','Standing Water','Oil'])
X[:,3] = le_rod.transform(X[:,3])

le_lgt = preprocessing.LabelEncoder()
le_lgt.fit(['Daylight','Dark - Street Lights On','Dark - No Street Lights','Unknown','Dusk','Dawn','Dark - Street Lights Off','Other','Dark - Unknown Lighting'])
X[:,4] = le_lgt.transform(X[:,4])

y=mdl_data['SEVERITYCODE']

X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
drugTree # it shows the default parameters
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
drugTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
predTree = drugTree.predict(X_testset)

# %%
print (predTree [0:5])
print (y_testset [0:5])
# Out:
# [1 1 1 1 1]
# 38576     1
# 107393    1
# 179179    1
# 182661    1
# 10079     1
# Name: SEVERITYCODE, dtype: int64

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.7244587647527333

# %%
Data=pd.DataFrame(X)
Data.columns=['ADDRTYPE','COLLISIONTYPE','WEATHER','ROADCOND','LIGHTCOND']
Data['SEVERITY']=y
convrt1 = {'SEVERITY':int}
convrt = {'ADDRTYPE':int,'COLLISIONTYPE':int,'WEATHER':int,'ROADCOND':int,'LIGHTCOND':int}
Data=Data.astype(convrt1)
Data=Data.astype(convrt)

viz = Data[['ADDRTYPE','COLLISIONTYPE','WEATHER','ROADCOND','LIGHTCOND','SEVERITY']]
viz.hist()
plt.show()

# %%
msk = np.random.rand(len(Data)) < 0.8
train = Data[msk]
test = Data[~msk]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['COLLISIONTYPE']])
train_y = np.asanyarray(train[['SEVERITY']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[-0.0212252]]
# Intercept:  [1.39866502]

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['COLLISIONTYPE']])
test_y = np.asanyarray(test[['SEVERITY']])
test_y_hat = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )
# Out:
# Mean absolute error: 0.42
# Residual sum of squares (MSE): 0.21
# R2-score: -58.12

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, mdl_data['SEVERITYCODE'], test_size=0.3, random_state=3)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (128902, 5) (128902,)
# Test set: (55244, 5) (55244,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 4
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %%
yhat = neigh.predict(X_test)
yhat[0:5]
# Out:
# array([1, 1, 1, 1, 1], dtype=int64)

# %%
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.7261485469581542
# Test set Accuracy:  0.7261422054883788

# %% [markdown]
# Logistic Regression model design

# %%
X = np.asarray(Data[['ADDRTYPE','COLLISIONTYPE','WEATHER','ROADCOND','LIGHTCOND']])
X[0:5]
# Out:
# array([[1, 0, 4, 8, 5],
#        [0, 9, 6, 8, 2],
#        [0, 5, 4, 0, 5],
#        [0, 4, 1, 0, 5],
#        [1, 0, 6, 8, 5]])

# %%
y = np.asarray(Data[['SEVERITY']])
y [0:5]
# Out:
# array([[2],
#        [1],
#        [1],
#        [1],
#        [2]])

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[ 1.38455029, -1.60024367,  0.33999573,  1.49309998,  0.35998332],
#        [-0.72225618,  1.61459033,  1.04920741,  1.49309998, -1.4057117 ],
#        [-0.72225618,  0.18577522,  0.33999573, -0.70378935,  0.35998332],
#        [-0.72225618, -0.17142856, -0.7238218 , -0.70378935,  0.35998332],
#        [ 1.38455029, -1.60024367,  1.04920741,  1.49309998,  0.35998332]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (147316, 5) (147316, 1)
# Test set: (36830, 5) (36830, 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
# Out:
# C:\Users\ashur\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
yhat = LR.predict(X_test)
yhat
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
yhat_prob = LR.predict_proba(X_test)
yhat_prob
# Out:
# array([[0.59476063, 0.40523937],
#        [0.75285663, 0.24714337],
#        [0.63011911, 0.36988089],
#        ...,
#        [0.76234696, 0.23765304],
#        [0.71662602, 0.28337398],
#        [0.7465677 , 0.2534323 ]])

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# C:\Users\ashur\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:664: FutureWarning: jaccard_similarity_score has been deprecated and replaced with jaccard_score. It will be removed in version 0.23. This implementation has surprising behavior for binary and multiclass classification tasks.
#   FutureWarning)
# 0.6885419494976921
